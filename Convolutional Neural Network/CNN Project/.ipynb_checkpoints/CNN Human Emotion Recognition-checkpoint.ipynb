# %% [markdown]
# ## Importing Libraries

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Sequential
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

import seaborn as sns 
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np

from keras.preprocessing import image
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_dir = "Dataset/train/" # Directory containing the training data
test_dir = "Dataset/validation/"  # Directory containing the validation data

# %% [markdown]
# ## Image Preprocessing with ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %% [markdown]
# ## Image Data Generators for Training and Validation

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 1522 images belonging to 2 classes.
# Found 432 images belonging to 2 classes.

# %% [markdown]
# ### Visualizations

# %%
import matplotlib.pyplot as plt

# Get a batch of images and labels from the generator
batch = next(train_generator)

# Display the images in a 4x4 grid with their corresponding labels
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10))
for i, ax in enumerate(axes.flat):
    ax.imshow(batch[0][i], cmap='gray') # display the image at index i of the batch on the current axis
    label_idx = batch[1][i].argmax() # get the index of the label for the image at index i of the batch
    label_map = {v:k for k,v in train_generator.class_indices.items()} # create a dictionary mapping the label index to the corresponding label name
    ax.set_title(label_map[label_idx]) # set the title of the current axis to the label name corresponding to the label index
    ax.axis('off') # turn off the axis ticks and labels
    
plt.show() # display the figure

# %% [markdown]
# ## CNN Modeling

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf 


# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 128 neurons and relu activation function
model.add(Dense(128, activation='relu'))
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add the output layer with 2 neurons (binary classification: happy or angry) and softmax activation function
model.add(Dense(2, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 46, 46, 32)        320
#
#  max_pooling2d_7 (MaxPoolin  (None, 23, 23, 32)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 23, 23, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 21, 21, 64)        18496
#
#  max_pooling2d_8 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 10, 10, 64)        0
#
#  flatten_4 (Flatten)         (None, 6400)              0
#
#  dense_9 (Dense)             (None, 128)               819328
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_10 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 838402 (3.20 MB)
# Trainable params: 838402 (3.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback to save the model's weights
# The filepath specifies where the weights should be saved
# The monitor argument specifies the metric to monitor for saving the best weights
# The save_best_only argument ensures that only the weights with the highest monitored metric value are saved
# The save_weights_only argument specifies to only save the weights (not the entire model)
# The mode argument specifies whether to maximize or minimize the monitored metric value (in this case, 'max' for accuracy)
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
# The batch_size specifies the number of samples per gradient update
# The epochs specifies the number of times to iterate over the entire training dataset
# The validation_data specifies the data to use for validation during training
# The callbacks argument specifies the callbacks to use during training (in this case, just the ModelCheckpoint callback)
history = model.fit(
    train_generator,
    batch_size=64,
    epochs=10,
    validation_data=validation_generator,
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/10
# 24/24 [==============================] - ETA: 0s - loss: 0.4164 - accuracy: 0.8601
# Epoch 1: val_accuracy improved from -inf to 0.67593, saving model to model_weights.h5
# 24/24 [==============================] - 4s 98ms/step - loss: 0.4164 - accuracy: 0.8601 - val_loss: 0.7014 - val_accuracy: 0.6759
# Epoch 2/10
# 24/24 [==============================] - ETA: 0s - loss: 0.4142 - accuracy: 0.8686
# Epoch 2: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 72ms/step - loss: 0.4142 - accuracy: 0.8686 - val_loss: 0.6393 - val_accuracy: 0.6759
# Epoch 3/10
# 24/24 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.8686
# Epoch 3: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 73ms/step - loss: 0.4097 - accuracy: 0.8686 - val_loss: 0.6568 - val_accuracy: 0.6759
# Epoch 4/10
# 24/24 [==============================] - ETA: 0s - loss: 0.4003 - accuracy: 0.8686
# Epoch 4: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 73ms/step - loss: 0.4003 - accuracy: 0.8686 - val_loss: 0.6398 - val_accuracy: 0.6759
# Epoch 5/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3973 - accuracy: 0.8686
# Epoch 5: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 72ms/step - loss: 0.3973 - accuracy: 0.8686 - val_loss: 0.6380 - val_accuracy: 0.6759
# Epoch 6/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.8686
# Epoch 6: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 73ms/step - loss: 0.3917 - accuracy: 0.8686 - val_loss: 0.6369 - val_accuracy: 0.6759
# Epoch 7/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3861 - accuracy: 0.8686
# Epoch 7: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 82ms/step - loss: 0.3861 - accuracy: 0.8686 - val_loss: 0.6670 - val_accuracy: 0.6759
# Epoch 8/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3849 - accuracy: 0.8686
# Epoch 8: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 79ms/step - loss: 0.3849 - accuracy: 0.8686 - val_loss: 0.6260 - val_accuracy: 0.6759
# Epoch 9/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3873 - accuracy: 0.8686
# Epoch 9: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 80ms/step - loss: 0.3873 - accuracy: 0.8686 - val_loss: 0.7082 - val_accuracy: 0.6759
# Epoch 10/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3915 - accuracy: 0.8686
# Epoch 10: val_accuracy did not improve from 0.67593
# 24/24 [==============================] - 2s 77ms/step - loss: 0.3915 - accuracy: 0.8686 - val_loss: 0.6586 - val_accuracy: 0.6759

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest')

# Validation data should not be augmented
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='binary',
    color_mode='grayscale')

validation_generator = val_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='binary',
    color_mode='grayscale')

# Create a new model or modify the existing model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model with a lower learning rate
opt = Adam(learning_rate=0.0001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=20,
    validation_data=validation_generator,
    validation_steps=len(validation_generator)
)
# Out:
# Found 1902 images belonging to 2 classes.
# Found 2166 images belonging to 2 classes.
# Epoch 1/20
# 30/30 [==============================] - 23s 728ms/step - loss: 0.4501 - accuracy: 0.8260 - val_loss: 0.6506 - val_accuracy: 0.6754
# Epoch 2/20
# 30/30 [==============================] - 3s 94ms/step - loss: 0.3974 - accuracy: 0.8686 - val_loss: 0.6511 - val_accuracy: 0.6754
# Epoch 3/20
# 30/30 [==============================] - 3s 95ms/step - loss: 0.3993 - accuracy: 0.8686 - val_loss: 0.6498 - val_accuracy: 0.6754
# Epoch 4/20
# 30/30 [==============================] - 3s 94ms/step - loss: 0.3918 - accuracy: 0.8686 - val_loss: 0.6485 - val_accuracy: 0.6754
# Epoch 5/20
# 30/30 [==============================] - 3s 96ms/step - loss: 0.3977 - accuracy: 0.8686 - val_loss: 0.6404 - val_accuracy: 0.6754
# Epoch 6/20
# 30/30 [==============================] - 3s 101ms/step - loss: 0.3928 - accuracy: 0.8686 - val_loss: 0.6376 - val_accuracy: 0.6754
# Epoch 7/20
# 30/30 [==============================] - 3s 99ms/step - loss: 0.3894 - accuracy: 0.8686 - val_loss: 0.6426 - val_accuracy: 0.6754
# Epoch 8/20
# 30/30 [==============================] - 3s 95ms/step - loss: 0.3904 - accuracy: 0.8686 - val_loss: 0.6443 - val_accuracy: 0.6754
# Epoch 9/20
# 30/30 [==============================] - 3s 95ms/step - loss: 0.3896 - accuracy: 0.8686 - val_loss: 0.6532 - val_accuracy: 0.6754
# Epoch 10/20
# 30/30 [==============================] - 3s 100ms/step - loss: 0.3931 - accuracy: 0.8686 - val_loss: 0.6533 - val_accuracy: 0.6754
# Epoch 11/20
# 30/30 [==============================] - 3s 98ms/step - loss: 0.3885 - accuracy: 0.8686 - val_loss: 0.6382 - val_accuracy: 0.6754
# Epoch 12/20
# 30/30 [==============================] - 3s 93ms/step - loss: 0.3891 - accuracy: 0.8686 - val_loss: 0.6379 - val_accuracy: 0.6754
# Epoch 13/20
# 30/30 [==============================] - 3s 98ms/step - loss: 0.3906 - accuracy: 0.8686 - val_loss: 0.6415 - val_accuracy: 0.6754
# Epoch 14/20
# 30/30 [==============================] - 3s 100ms/step - loss: 0.3881 - accuracy: 0.8686 - val_loss: 0.6414 - val_accuracy: 0.6754
# Epoch 15/20
# 30/30 [==============================] - 3s 94ms/step - loss: 0.3907 - accuracy: 0.8686 - val_loss: 0.6352 - val_accuracy: 0.6754
# Epoch 16/20
# 30/30 [==============================] - 3s 98ms/step - loss: 0.3842 - accuracy: 0.8686 - val_loss: 0.6403 - val_accuracy: 0.6754
# Epoch 17/20
# 30/30 [==============================] - 3s 97ms/step - loss: 0.3831 - accuracy: 0.8686 - val_loss: 0.6410 - val_accuracy: 0.6754
# Epoch 18/20
# 30/30 [==============================] - 3s 101ms/step - loss: 0.3851 - accuracy: 0.8686 - val_loss: 0.6437 - val_accuracy: 0.6754
# Epoch 19/20
# 30/30 [==============================] - 3s 111ms/step - loss: 0.3897 - accuracy: 0.8686 - val_loss: 0.6307 - val_accuracy: 0.6754
# Epoch 20/20
# 30/30 [==============================] - 4s 120ms/step - loss: 0.3851 - accuracy: 0.8686 - val_loss: 0.6448 - val_accuracy: 0.6754

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization

# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest')

# Validation data should not be augmented
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='binary',
    color_mode='grayscale')

validation_generator = val_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='binary',
    color_mode='grayscale')

# Create a new model or modify the existing model with batch normalization
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model with a lower learning rate
opt = Adam(learning_rate=0.0001)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=20,
    validation_data=validation_generator,
    validation_steps=len(validation_generator)
)
# Out:
# Found 1902 images belonging to 2 classes.
# Found 2166 images belonging to 2 classes.
# Epoch 1/20
# 30/30 [==============================] - 5s 113ms/step - loss: 1.0329 - accuracy: 0.4905 - val_loss: 0.7441 - val_accuracy: 0.3246
# Epoch 2/20
# 30/30 [==============================] - 4s 122ms/step - loss: 0.9787 - accuracy: 0.5100 - val_loss: 0.7253 - val_accuracy: 0.3306
# Epoch 3/20
# 30/30 [==============================] - 4s 119ms/step - loss: 0.8946 - accuracy: 0.5452 - val_loss: 0.6975 - val_accuracy: 0.4778
# Epoch 4/20
# 30/30 [==============================] - 3s 111ms/step - loss: 0.9163 - accuracy: 0.5226 - val_loss: 0.6734 - val_accuracy: 0.6339
# Epoch 5/20
# 30/30 [==============================] - 3s 116ms/step - loss: 0.8327 - accuracy: 0.5526 - val_loss: 0.6488 - val_accuracy: 0.6731
# Epoch 6/20
# 30/30 [==============================] - 3s 110ms/step - loss: 0.8740 - accuracy: 0.5452 - val_loss: 0.6451 - val_accuracy: 0.6667
# Epoch 7/20
# 30/30 [==============================] - 3s 112ms/step - loss: 0.7987 - accuracy: 0.5789 - val_loss: 0.6292 - val_accuracy: 0.6777
# Epoch 8/20
# 30/30 [==============================] - 3s 111ms/step - loss: 0.8164 - accuracy: 0.5778 - val_loss: 0.6307 - val_accuracy: 0.6777
# Epoch 9/20
# 30/30 [==============================] - 3s 114ms/step - loss: 0.8082 - accuracy: 0.5631 - val_loss: 0.6462 - val_accuracy: 0.6630
# Epoch 10/20
# 30/30 [==============================] - 3s 110ms/step - loss: 0.7735 - accuracy: 0.5836 - val_loss: 0.6258 - val_accuracy: 0.6787
# Epoch 11/20
# 30/30 [==============================] - 3s 111ms/step - loss: 0.7280 - accuracy: 0.6162 - val_loss: 0.6271 - val_accuracy: 0.6722
# Epoch 12/20
# 30/30 [==============================] - 3s 112ms/step - loss: 0.7435 - accuracy: 0.6057 - val_loss: 0.6378 - val_accuracy: 0.6570
# Epoch 13/20
# 30/30 [==============================] - 3s 116ms/step - loss: 0.7177 - accuracy: 0.6178 - val_loss: 0.6393 - val_accuracy: 0.6473
# Epoch 14/20
# 30/30 [==============================] - 4s 117ms/step - loss: 0.6985 - accuracy: 0.6441 - val_loss: 0.6345 - val_accuracy: 0.6602
# Epoch 15/20
# 30/30 [==============================] - 3s 115ms/step - loss: 0.6921 - accuracy: 0.6288 - val_loss: 0.6397 - val_accuracy: 0.6524
# Epoch 16/20
# 30/30 [==============================] - 4s 117ms/step - loss: 0.6769 - accuracy: 0.6425 - val_loss: 0.6351 - val_accuracy: 0.6570
# Epoch 17/20
# 30/30 [==============================] - 3s 115ms/step - loss: 0.6777 - accuracy: 0.6614 - val_loss: 0.6232 - val_accuracy: 0.6560
# Epoch 18/20
# 30/30 [==============================] - 3s 110ms/step - loss: 0.6482 - accuracy: 0.6672 - val_loss: 0.6175 - val_accuracy: 0.6722
# Epoch 19/20
# 30/30 [==============================] - 3s 111ms/step - loss: 0.6546 - accuracy: 0.6725 - val_loss: 0.6081 - val_accuracy: 0.6773
# Epoch 20/20
# 30/30 [==============================] - 3s 110ms/step - loss: 0.6405 - accuracy: 0.6761 - val_loss: 0.5931 - val_accuracy: 0.6911

# %% [markdown]
# ## Evaluation

# %%
# Generate generalization metrics
validation_loss, validation_acc = model.evaluate_generator(validation_generator)
print('Validation loss:', validation_loss, '\t Validation accuracy:', validation_acc)
# Out:
# C:\Users\arunk\AppData\Local\Temp\ipykernel_9680\318391605.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   validation_loss, validation_acc = model.evaluate_generator(validation_generator)
# Validation loss: 0.5931380391120911 	 Validation accuracy: 0.6911357045173645

# %% [markdown]
# ## Training and validation loss curves

# %%
# Plot the train and validation loss

train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the train and validation accuracy
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Training and validation accuracy curves

# %%
# Load an image to predict
img_path = "confusion-2.jpeg"
img = image.load_img(img_path, target_size=(48, 48), color_mode='grayscale')  # Load image and resize it to (48, 48) and convert it to grayscale
img_array = image.img_to_array(img)  # Convert the image to a numpy array
img_array = np.expand_dims(img_array, axis=0)  # Add an extra dimension to the array to make it suitable for model input
img_array /= 255.  # Normalize the pixel values between 0 and 1

# Make a prediction
prediction = model.predict(img_array)  # Predict the emotion label for the image

# Get the predicted label
label_map = {v:k for k,v in train_generator.class_indices.items()}  # Map the class indices to the corresponding emotion labels
predicted_label = label_map[np.argmax(prediction)]  # Get the emotion label with the highest predicted probability
print(" Emotion predicted of this image is", predicted_label)  # Print the predicted emotion label
# Out:
# 1/1 [==============================] - 0s 20ms/step
#  Emotion predicted of this image is angry

# %%
plt.imshow(image.load_img(img_path))
